# %%
import numpy
import sys
import os
import pickle
import torch
sys.path.append('/usr0/home/yuncheng/MultiBench/')
from supervised_learning import test
from ensemble import test as test_ensemble
from get_data import get_dataloader
from rus import *

# %%
if os.path.isfile('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle'):
    with open('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle', 'rb') as f:
        results = pickle.load(f)
else:
    results = dict()
for method in ['additive', 'agree', 'align', 'early_fusion', 'elem', 'mfm', 'mi', 'mult', 'outer', 'lower']:
    if method not in results:
        results[method] = dict()
    for SETTING in ['redundancy', 'uniqueness0', 'uniqueness1', 'synergy', 'mix1', 'mix2', 'mix3']:
        print(SETTING)
        data_path = '/usr0/home/yuncheng/MultiBench/synthetic/DATA_{}.pickle'.format(SETTING)
        saved_model = '/usr0/home/yuncheng/MultiBench/synthetic/experiments/{}/{}_{}_best.pt'.format(SETTING, SETTING, method)
        saved_cluster = '/usr0/home/yuncheng/MultiBench/synthetic/experiments/{}/{}_{}_cluster.pickle'.format(SETTING, SETTING, method)
        _, _, _, testdata = get_dataloader(path=data_path, keys=['0','1','label'], modalities=[1,1], batch_size=128, num_workers=4)
        model = torch.load(saved_model).cuda()
        num_params = sum([p.numel() for p in model.parameters()])
        if method in ['additive', 'agree', 'align']:
            acc = test_ensemble(model, testdata, no_robust=True, criterion=torch.nn.CrossEntropyLoss(), save_preds=saved_cluster)
        else:
            acc = test(model, testdata, no_robust=True, criterion=torch.nn.CrossEntropyLoss(), save_preds=saved_cluster)
        with open(saved_cluster, 'rb') as f:
            preds = pickle.load(f)
        with open('/usr0/home/yuncheng/MultiBench/synthetic/DATA_{}_cluster.pickle'.format(SETTING), 'rb') as f:
            cluster = pickle.load(f)
        pred_results = (cluster['test']['0'], cluster['test']['1'], preds.reshape(-1,1))
        P, maps = convert_data_to_distribution(*pred_results)
        tmp = get_measure(P)
        if SETTING not in results[method]:
            results[method] = tmp
        else:
            for k in tmp:
                results[method][SETTING][k] = tmp[k]
        results[method][SETTING]['acc'] = acc
        results[method][SETTING]['params'] = num_params
        print()

with open('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle', 'wb') as f:
    pickle.dump(results, f)
# Out:
# redundancy
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.5307, device='cuda:0')
# acc: 0.7372222222222222
# Redundancy 0.45532313900963794
# Unique 0.08025620779668531
# Unique 1.2782317862373846e-06
# Synergy 0.03543063094107235
#
# uniqueness0
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# /usr0/home/yuncheng/miniconda3/envs/multibench/lib/python3.9/site-packages/cvxpy/problems/problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# loss: tensor(0.6069, device='cuda:0')
# acc: 0.6738888888888889
# Redundancy 0.021131596509711026
# Unique 0.2658035769291154
# Unique 2.609217910494956e-09
# Synergy 0.048664295194861484
#
# uniqueness1
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# ...

# %%
for SETTING in ['redundancy', 'uniqueness0', 'uniqueness1', 'synergy', 'mix1', 'mix2', 'mix3', 'mix4', 'mix5', 'mix6']:
    with open('/usr0/home/yuncheng/MultiBench/synthetic/DATA_{}_cluster.pickle'.format(SETTING), 'rb') as f:
        cluster = pickle.load(f)
    results = (cluster['test']['0'], cluster['test']['1'], cluster['test']['label'])
    P, maps = convert_data_to_distribution(*results)
    get_measure(P)
    print()
# Out:
# Redundancy 0.16721953678967238
# Unique 0.009443059215327298
# Unique 0.00038723549898728936
# Synergy 0.05407597605044967
#
# Redundancy 0.0024068776832209815
# Unique 0.17168997263936803
# Unique -3.9762788372355886e-17
# Synergy 0.053745916375025876
#
# Redundancy 0.004109998201795223
# Unique 4.739394431722425e-17
# Unique 0.16024362610457085
# Synergy 0.047320072834599824
#
# Redundancy 0.0740888062450043
# Unique 0.010071939432917378
# Unique 0.0005577240092090323
# Synergy 0.1381926821869899
#
# Redundancy 0.05076955525118054
# Unique 0.005163602945388254
# Unique 0.0012951574877414992
# Synergy 0.07132778066395776
#
# Redundancy 0.05399747675209331
# Unique 0.05768927022274116
# Unique 7.126959113402868e-16
# Synergy 0.07139916901767802
#
# Redundancy 0.07978805424537334
# Unique 0.008983824324279941
# Unique 0.0013647931713488403
# Synergy 0.11584163577704519
#
# Redundancy 0.09086883240778226
# Unique 0.0027345520262268383
# Unique 0.0056027411357744425
# ...

# %%
if os.path.isfile('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle'):
    with open('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle', 'rb') as f:
        results = pickle.load(f)
else:
    results = dict()
for method in ['additive', 'agree', 'align', 'early_fusion', 'elem', 'mfm', 'mi', 'mult', 'outer']:
# for method in ['tf']:
    print(method)
    for SETTING in ['redundancy', 'uniqueness0', 'uniqueness1', 'synergy', 'mix1', 'mix2', 'mix3', 'mix4', 'mix5', 'mix6']:
        print(SETTING)
        for i, modality in enumerate([[1,0], [0,1]]):
            print('unimodal', i)
            data_path = '/usr0/home/yuncheng/MultiBench/synthetic/DATA_{}.pickle'.format(SETTING)
            saved_model = '/usr0/home/yuncheng/MultiBench/synthetic/experiments/{}/{}_{}_best.pt'.format(SETTING, SETTING, method)
            _, _, _, testdata = get_dataloader(path=data_path, keys=['0','1','label'], modalities=modality, batch_size=128, num_workers=4)
            model = torch.load(saved_model).cuda()
            if method in ['additive', 'agree', 'align']:
                acc = test_ensemble(model, testdata, no_robust=True, criterion=torch.nn.CrossEntropyLoss())
            else:
                acc = test(model, testdata, no_robust=True, criterion=torch.nn.CrossEntropyLoss())
            results[method][SETTING]['unimodal{}_acc'.format(i)] = acc
        print()

with open('/usr0/home/yuncheng/MultiBench/synthetic/experiments/results.pickle', 'wb') as f:
    pickle.dump(results, f)
# Out:
# additive
# redundancy
# unimodal 0
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.7040, device='cuda:0')
# acc: 0.5305555555555556
# unimodal 1
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.5100, device='cuda:0')
# acc: 0.7477777777777778
#
# uniqueness0
# unimodal 0
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.5984, device='cuda:0')
# acc: 0.6883333333333334
# unimodal 1
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.7021, device='cuda:0')
# acc: 0.49277777777777776
#
# uniqueness1
# unimodal 0
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.7847, device='cuda:0')
# acc: 0.4905555555555556
# unimodal 1
# Train data: 14000
# Valid data 1: 2100
# Valid data 2: 2100
# Test data: 1800
# loss: tensor(0.5169, device='cuda:0')
# ...

# %%
results = dict()
for setting in ['redundancy', 'uniqueness0', 'uniqueness1', 'synergy', 'mix1', 'mix2', 'mix3', 'mix4', 'mix5', 'mix6']:
    with open('/usr0/home/yuncheng/MultiBench/synthetic/DATA_{}_cluster.pickle'.format(setting), 'rb') as f:
        dataset = pickle.load(f)
    print(setting)
    data = (dataset['test']['0'], dataset['test']['1'], dataset['test']['label'])
    P, maps = convert_data_to_distribution(*data)
    result = get_measure(P)
    results[setting] = result
    print()

with open('/usr0/home/yuncheng/MultiBench/synthetic/experiments/datasets.pickle', 'wb') as f:
    pickle.dump(results, f)
# Out:
# redundancy
# Redundancy 0.16721953678967238
# Unique 0.009443059215327298
# Unique 0.00038723549898728936
# Synergy 0.05407597605044967
#
# uniqueness0
# Redundancy 0.0024068776832209815
# Unique 0.17168997263936803
# Unique -3.9762788372355886e-17
# Synergy 0.053745916375025876
#
# uniqueness1
# Redundancy 0.004109998201795223
# Unique 4.739394431722425e-17
# Unique 0.16024362610457085
# Synergy 0.047320072834599824
#
# synergy
# Redundancy 0.0740888062450043
# Unique 0.010071939432917378
# Unique 0.0005577240092090323
# Synergy 0.1381926821869899
#
# mix1
# Redundancy 0.05076955525118054
# Unique 0.005163602945388254
# Unique 0.0012951574877414992
# Synergy 0.07132778066395776
#
# mix2
# Redundancy 0.05399747675209331
# Unique 0.05768927022274116
# Unique 7.126959113402868e-16
# Synergy 0.07139916901767802
#
# mix3
# Redundancy 0.07978805424537334
# Unique 0.008983824324279941
# Unique 0.0013647931713488403
# Synergy 0.11584163577704519
#
# mix4
# Redundancy 0.09086883240778226
# ...
